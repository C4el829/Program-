# %%
x = int(input("x = "))
if x > 0:
    print("Eyreg")
elif x < 0:
    print("Surug")
else:
    print("Teg")
# Out:
# x =  -13
# Surug

# %%
pw = input("Nuuts ug: ")
if len(pw) >= 8 and "@" in pw:
    print("Zuwshuuruw")
else:
    print("Shaardlaga hangahgui")
# Out:
# Nuuts ug:  Ugusgdus@
# Zuwshuuruw

# %%
total = float(input("niit une"))

if total > 100000:
    discount = 0.10
elif total >= 50000:
    discount = 0.05
else:
    discount = 0.0

pay = total * (1 - discount)
print("hungulult:", discount*100, "%")
print("tuluh:", pay)
# Out:
# niit une 150000
# hungulult: 10.0 %
# tuluh: 135000.0

# %%
a = int(input("a= "))
b = int(input("b= "))
c = int(input("c= "))
if a > b and c % 2 == 0:
    print("Yes")
else:
    print("No")
# Out:
# a=  18
# b=  15
# c=  14
# Yes

# %%
age= int(input("Nas="))
if (age < 0 or age < 120):
    print("Valid")
else:
    print("Invalid")
# Out:
# Nas= 150
# Invalid

# %%
month= int(input("month(1-12)="))
if month in (12,1,2):
    print("Uvul")
elif month in (3,4,5):
    print("Havar")
elif month in (6,7,8):
    print("Zun")
elif month in (9,10,11):
    print("Namar")
else:
    print("Invalid")
# Out:
# month(1-12)= 3
# Havar

# %%
hours = int(input("Enter worked hours"))
rate = int(input("Enter hours rate"))
if hours < 0 or rate < 0:
    print("Invalid Input")
else:
    if hours <= 40:
        salary = hours * rate
    else:
        salary = 40 * rate + (hours - 40) * rate * 1.5
    print("salary=",salary)
# Out:
# Enter worked hours 8
# Enter hours rate 6250
# salary= 50000

# %%
a = int(input("a="))
b = int(input("b="))
c = int(input("c="))

if a <= 0 or b <= 0 or c <= 0 or a + b <= c or a + c <= b or b + c <= a:
    print("NOT A TRIANGLE")
else:
    if a == b == c:
        print("EQUILATERAL")
    elif a == b or a == c or b == c:
        print("ISOSCELES")
    else:
        print("SCALENE")
# Out:
# a= 6
# b= 6
# c= 5
# ISOSCELES
